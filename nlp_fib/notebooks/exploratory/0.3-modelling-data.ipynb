# %%
import pandas as pd
df = pd.read_csv('/Users/pujaarajan/Documents/GitHub/nlp_fib/data/raw/enron_05_17_2015_with_labels_v2_100K_chunk_1_of_6.csv', usecols= [*range(2, 6),13], dtype={13:str})

# %% [markdown]
# # Pytorch Bidirectional Language Model
# ## https://gist.github.com/tokestermw/912042a85a1d53169c2dc7253dca55f6#file-birnnlm_pytorch-py

# %%
import torch, torch.nn as nn
from torch.autograd import Variable

text = ['BOS', 'How', 'are', 'you', 'EOS']
seq_len = len(text)
batch_size = 1
embedding_size = 1
hidden_size = 1
output_size = 1

random_input = Variable(
    torch.FloatTensor(seq_len, batch_size, embedding_size).normal_(), requires_grad=False)

print(random_input)

bi_rnn = torch.nn.RNN(input_size=embedding_size, hidden_size=hidden_size, num_layers=1, batch_first=False, bidirectional=True)

print (bi_rnn)

bi_output, bi_hidden = bi_rnn(random_input)

# stagger
forward_output, backward_output = bi_output[:-2, :, :hidden_size], bi_output[2:, :, hidden_size:]
staggered_output = torch.cat((forward_output, backward_output), dim=-1)

linear = nn.Linear(hidden_size * 2, output_size)

print(linear)

# only predict on words
labels = random_input[1:-1]

print (labels)

# for language models, use cross-entropy :)
loss = nn.MSELoss()
output = loss(linear(staggered_output), labels)
# Out:
# tensor([[[-0.0992]],
#
#         [[-1.6376]],
#
#         [[ 0.7857]],
#
#         [[ 0.4047]],
#
#         [[ 1.7969]]])
# RNN(1, 1, bidirectional=True)
# Linear(in_features=2, out_features=1, bias=True)
# tensor([[[-1.6376]],
#
#         [[ 0.7857]],
#
#         [[ 0.4047]]])

# %%
output
# Out:
# tensor(1.2804, grad_fn=<MseLossBackward>)

# %% [markdown]
# # Word2Vec

# %%
# Out:
#                       Date                                    From  \
# 0      2001-05-14 23:39:00  frozenset({'phillip.allen@enron.com'})
# 1      2001-05-04 20:51:00  frozenset({'phillip.allen@enron.com'})
# 2      2000-10-18 10:00:00  frozenset({'phillip.allen@enron.com'})
# 3      2000-10-23 13:13:00  frozenset({'phillip.allen@enron.com'})
# 4      2000-08-31 12:07:00  frozenset({'phillip.allen@enron.com'})
# 5      2000-08-31 11:17:00  frozenset({'phillip.allen@enron.com'})
# 6      2000-08-22 14:44:00  frozenset({'phillip.allen@enron.com'})
# 7      2000-07-14 13:59:00  frozenset({'phillip.allen@enron.com'})
# 8      2000-10-17 09:26:00  frozenset({'phillip.allen@enron.com'})
# 9      2000-10-16 13:44:00  frozenset({'phillip.allen@enron.com'})
# 10     2000-10-16 13:42:00  frozenset({'phillip.allen@enron.com'})
# 11     2000-10-13 13:45:00  frozenset({'phillip.allen@enron.com'})
# 12     2000-10-09 14:16:00  frozenset({'phillip.allen@enron.com'})
# 13     2000-10-09 14:00:00  frozenset({'phillip.allen@enron.com'})
# 14     2000-10-05 13:26:00  frozenset({'phillip.allen@enron.com'})
# 15     2000-10-05 12:55:00  frozenset({'phillip.allen@enron.com'})
# 16     2000-10-04 16:23:00  frozenset({'phillip.allen@enron.com'})
# 17     2001-05-04 18:26:00  frozenset({'phillip.allen@enron.com'})
# 18     2000-10-03 16:30:00  frozenset({'phillip.allen@enron.com'})
# 19     2000-10-03 16:15:00  frozenset({'phillip.allen@enron.com'})
# 20     2000-10-03 16:13:00  frozenset({'phillip.allen@enron.com'})
# 21     2000-10-03 10:17:00  frozenset({'phillip.allen@enron.com'})
# 22     2000-10-02 09:19:00  frozenset({'phillip.allen@enron.com'})
# 23     2000-09-28 13:17:00  frozenset({'phillip.allen@enron.com'})
# 24     2000-09-28 12:56:00  frozenset({'phillip.allen@enron.com'})
# 25     2000-09-26 16:28:00  frozenset({'phillip.allen@enron.com'})
# 26     2000-09-26 16:26:00  frozenset({'phillip.allen@enron.com'})
# 27     2000-09-26 14:01:00  frozenset({'phillip.allen@enron.com'})
# 28     2001-05-03 22:57:00  frozenset({'phillip.allen@enron.com'})
# 29     2000-09-26 12:11:00  frozenset({'phillip.allen@enron.com'})
# ...                    ...                                     ...
# 99970  2000-01-07 16:25:00   frozenset({'daren.farmer@enron.com'})
# 99971  2000-01-07 12:12:00   frozenset({'daren.farmer@enron.com'})
# 99972  2000-01-07 11:27:00   frozenset({'daren.farmer@enron.com'})
# 99973  2000-01-07 11:25:00   frozenset({'daren.farmer@enron.com'})
# 99974  2000-01-07 10:38:00   frozenset({'daren.farmer@enron.com'})
# 99975  2000-01-07 07:28:00   frozenset({'daren.farmer@enron.com'})
# 99976  2000-01-06 16:05:00   frozenset({'daren.farmer@enron.com'})
# 99977  2000-01-06 15:58:00   frozenset({'daren.farmer@enron.com'})
# 99978  2000-01-06 15:56:00   frozenset({'daren.farmer@enron.com'})
# 99979  2000-01-06 15:55:00   frozenset({'daren.farmer@enron.com'})
# 99980  2000-01-05 15:32:00   frozenset({'daren.farmer@enron.com'})
# 99981  2000-01-05 14:46:00   frozenset({'daren.farmer@enron.com'})
# 99982  2000-01-05 14:11:00   frozenset({'daren.farmer@enron.com'})
# 99983  2000-01-05 11:26:00   frozenset({'daren.farmer@enron.com'})
# 99984  2000-01-05 07:23:00   frozenset({'daren.farmer@enron.com'})
# 99985  2000-01-05 07:17:00   frozenset({'daren.farmer@enron.com'})
# 99986  2000-01-04 16:15:00   frozenset({'daren.farmer@enron.com'})
# 99987  1999-12-30 13:46:00   frozenset({'daren.farmer@enron.com'})
# 99988  1999-12-29 15:18:00   frozenset({'daren.farmer@enron.com'})
# 99989  1999-12-29 06:58:00   frozenset({'daren.farmer@enron.com'})
# 99990  1999-12-29 06:56:00   frozenset({'daren.farmer@enron.com'})
# 99991  1999-12-28 10:24:00   frozenset({'daren.farmer@enron.com'})
# 99992  2001-03-14 23:30:00   frozenset({'daren.farmer@enron.com'})
# 99993  1999-12-27 16:16:00   frozenset({'daren.farmer@enron.com'})
# 99994  1999-12-27 12:35:00   frozenset({'daren.farmer@enron.com'})
# 99995  1999-12-27 08:11:00   frozenset({'daren.farmer@enron.com'})
# 99996  1999-12-22 07:14:00   frozenset({'daren.farmer@enron.com'})
# 99997  1999-12-22 07:02:00   frozenset({'daren.farmer@enron.com'})
# 99998  1999-12-22 06:52:00   frozenset({'daren.farmer@enron.com'})
# 99999  1999-12-20 16:05:00   frozenset({'daren.farmer@enron.com'})
#
#                                                       To  \
# 0                    frozenset({'tim.belden@enron.com'})
# 1                 frozenset({'john.lavorato@enron.com'})
# 2                  frozenset({'leah.arsdall@enron.com'})
# 3                   frozenset({'randall.gay@enron.com'})
# 4                    frozenset({'greg.piper@enron.com'})
# 5                    frozenset({'greg.piper@enron.com'})
# 6      frozenset({'david.l.johnson@enron.com', 'john....
# 7                frozenset({'joyce.teixeira@enron.com'})
# 8                    frozenset({'mark.scott@enron.com'})
# 9                         frozenset({'zimam@enron.com'})
# 10             frozenset({'buck.buckner@honeywell.com'})
# 11             frozenset({'stagecoachmama@hotmail.com'})
# 12                  frozenset({'keith.holst@enron.com'})
# 13                  frozenset({'keith.holst@enron.com'})
# 14               frozenset({'david.delainey@enron.com'})
# 15                 frozenset({'paula.harris@enron.com'})
# 16                   frozenset({'ina.rangel@enron.com'})
# 17              frozenset({'tim.heizenrader@enron.com'})
# 18                   frozenset({'pallen70@hotmail.com'})
# 19                   frozenset({'ina.rangel@enron.com'})
# 20                     frozenset({'bs_stone@yahoo.com'})
# 21              frozenset({'stouchstone@natsource.com'})
# 22                     frozenset({'bs_stone@yahoo.com'})
# 23                           frozenset({'lkuch@mh.com'})
# 24                frozenset({'jeffrey.hodge@enron.com'})
# 25                       frozenset({'kholst@enron.com'})
# 26                   frozenset({'pallen70@hotmail.com'})
# 27                   frozenset({'ina.rangel@enron.com'})
# 28                     frozenset({'rlehmann@yahoo.com'})
# 29              frozenset({'cindy.cicchetti@enron.com'})
# ...                                                  ...
# 99970            frozenset({'aggie_chic02@hotmail.com'})
# 99971          frozenset({'donald.reinhardt@enron.com'})
# 99972                frozenset({'thu.nguyen@enron.com'})
# 99973              frozenset({'robert.lloyd@enron.com'})
# 99974            frozenset({'richard.pinion@enron.com'})
# 99975             frozenset({'stella.morris@enron.com'})
# 99976            frozenset({'heather.choate@enron.com'})
# 99977               frozenset({'ami.chokshi@enron.com'})
# 99978               frozenset({'ami.chokshi@enron.com'})
# 99979                frozenset({'pat.clynes@enron.com'})
# 99980                frozenset({'joanie.ngo@enron.com'})
# 99981               frozenset({'ami.chokshi@enron.com'})
# 99982               frozenset({'ami.chokshi@enron.com'})
# 99983            frozenset({'melissa.graves@enron.com'})
# 99984             frozenset({'imelda.frayre@enron.com'})
# 99985             frozenset({'imelda.frayre@enron.com'})
# 99986             frozenset({'imelda.frayre@enron.com'})
# 99987                frozenset({'pat.clynes@enron.com'})
# 99988         frozenset({'charlotte.hawkins@enron.com'})
# 99989          frozenset({'carlos.rodriguez@enron.com'})
# 99990                frozenset({'pat.clynes@enron.com'})
# 99991                frozenset({'pat.clynes@enron.com'})
# 99992              frozenset({'aimee.lannou@enron.com'})
# 99993          frozenset({'carlos.rodriguez@enron.com'})
# 99994  frozenset({'pat.clynes@enron.com', 'ami.choksh...
# 99995          frozenset({'carlos.rodriguez@enron.com'})
# 99996             frozenset({'stella.morris@enron.com'})
# 99997              frozenset({'aimee.lannou@enron.com'})
# 99998                frozenset({'pat.clynes@enron.com'})
# 99999              frozenset({'julie.meyers@enron.com'})
#
#                                                  Subject  \
# 0                                                    NaN
# 1                                                    Re:
# 2                                               Re: test
# 3                                                    NaN
# 4                                              Re: Hello
# 5                                              Re: Hello
# 6                                                    NaN
# 7                           Re: PRC review - phone calls
# 8                         Re: High Speed Internet Access
# 9      FW: fixed forward or other Collar floor gas pr...
# 10     Re: FW: fixed forward or other Collar floor ga...
# 11                                                   NaN
# 12           Consolidated positions: Issues & To Do list
# 13           Consolidated positions: Issues & To Do list
# 14                                                   NaN
# 15                                  Re: 2001 Margin Plan
# 16                  Var, Reporting and Resources Meeting
# 17                                                   NaN
# 18                                              Westgate
# 19            Meeting re: Storage Strategies in the West
# 20                                                   NaN
# 21                            Re: Not business related..
# 22                       Re: Original Sept check/closing
# 23                                        San Juan Index
# 24                                        San Juan Index
# 25                                  Investment Structure
# 26                                  Investment Structure
# 27                                                   NaN
# 28                                                   NaN
# 29                        Re: Gas Trading Vision meeting
# ...                                                  ...
# 99970                                      Re: new email
# 99971                Re: C&E Operating, 11/99 production
# 99972  Re: Bridge Back Error - Sitara deal# 118977 No...
# 99973     Bridge Back Error - Sitara deal# 118977 Nov 99
# 99974             Re: Texas Desk December Summary Report
# 99975         Re: UA4 for Meter 8608 - 6/98 - deal 96731
# 99976  Re: **Reschedule**Recurring Logistics Unify Me...
# 99977            Re: Request for Application Report List
# 99978                       Columbia Energy History Data
# 99979                  Recurring Logistics Unify Meeting
# 99980                          Re: TXU Fuel for December
# 99981        Enron Actuals for December 10 thru 12, 1999
# 99982                 Enron Actuals for December 9, 1999
# 99983                                   Re: Nom for Feb.
# 99984                                  Tx Desk Marketers
# 99985                                Re: Sitara Security
# 99986                                    Sitara Security
# 99987                                        Plan update
# 99988            Re: Meter 74, December BRIDGEBACK ERROR
# 99989  Revision - Black Marlin - meter 986782 for 8/9...
# 99990                                           Y2K deal
# 99991      Unify Production back - EOL Deals highlighted
# 99992                                     Re: deal 34342
# 99993                               Unify Close Schedule
# 99994            displaying 4 digit year on your desktop
# 99995                        January Production Estimate
# 99996        Re: UA4 - Meter 1441 for 11/97 - Falfurrias
# 99997                                    Re: tufco 11/99
# 99998                               Unify Close Schedule
# 99999                                Re: Evergreen deals
#
#                                                  content
# 0                                   Here is our forecast
# 1      Traveling to have a business meeting takes the...
# 2                          test successful. way to go!!!
# 3      Randy, Can you send me a schedule of the salar...
# 4                      Let's shoot for Tuesday at 11:45.
# 5      Greg, How about either next Tuesday or Thursda...
# 6      Please cc the following distribution list with...
# 7                       any morning between 10 and 11:30
# 8      1. login: pallen pw: ke9davis I don't think th...
# 9      ---------------------- Forwarded by Phillip K ...
# 10     Mr. Buckner, For delivered gas behind San Dieg...
# 11     Lucy, Here are the rentrolls: Open them and sa...
# 12     ---------------------- Forwarded by Phillip K ...
# 13     ---------------------- Forwarded by Phillip K ...
# 14     Dave, Here are the names of the west desk memb...
# 15                     Paula, 35 million is fine Phillip
# 16     ---------------------- Forwarded by Phillip K ...
# 17     Tim, mike grigsby is having problems with acce...
# 18     ---------------------- Forwarded by Phillip K ...
# 19     ---------------------- Forwarded by Phillip K ...
# 20     Brenda, Please use the second check as the Oct...
# 21     I think Fletch has a good CPA. I am still doin...
# 22     Brenda, Please use the second check as my Octo...
# 23     ---------------------- Forwarded by Phillip K ...
# 24     Liane, As we discussed yesterday, I am concern...
# 25     ---------------------- Forwarded by Phillip K ...
# 26     ---------------------- Forwarded by Phillip K ...
# 27     ---------------------- Forwarded by Phillip K ...
# 28     Reagan, Just wanted to give you an update. I h...
# 29     Nymex expiration is during this time frame. Pl...
# ...                                                  ...
# 99970  Why do you keep changing your e-mail address? ...
# 99971  I added 11/29-30 to deal 132030. Give me a cal...
# 99972  I have asked Robert Lloyd to look into this. H...
# 99973  Robert, Please look into this . D. -----------...
# 99974  Richard, Please add Pat Clynes to your distrib...
# 99975  Stella, The deal is in Sitara (#11121). Howeve...
# 99976  Heather, Please include Pat Clynes on all Logi...
# 99977  ---------------------- Forwarded by Daren J Fa...
# 99978  FYI ---------------------- Forwarded by Daren ...
# 99979  Pat, You should have been included on this. I ...
# 99980  Ami Chokshi will be sending this to you once i...
# 99981  ---------------------- Forwarded by Daren J Fa...
# 99982  ---------------------- Forwarded by Daren J Fa...
# 99983  Pre-bid will be on Monday 1/24. D Enron North ...
# 99984  Imelda, The following people are marketers on ...
# 99985  Imelda, These people still need the Sitara acc...
# 99986  Imelda, The following people (HPL Logistics) n...
# 99987  ---------------------- Forwarded by Daren J Fa...
# 99988  Charlotte, This is a desk-to-desk deal. You ne...
# 99989  Carlos, Please look into your Black Marlin inf...
# 99990  ---------------------- Forwarded by Daren J Fa...
# 99991  ---------------------- Forwarded by Daren J Fa...
# 99992  We have a buyback under HPL (#586534). ENA had...
# 99993  ---------------------- Forwarded by Daren J Fa...
# 99994  ---------------------- Forwarded by Daren J Fa...
# 99995  ---------------------- Forwarded by Daren J Fa...
# 99996  What occurred at this point in prior months? W...
# 99997  Aimee, PG&E's numbers are correct. Aimee Lanno...
# 99998  ---------------------- Forwarded by Daren J Fa...
# 99999  Vintage should be 93730. Julie Meyers 12/20/99...
#
# [100000 rows x 5 columns]
